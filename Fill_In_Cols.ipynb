# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('Crime_Dataset_Coursework1.csv')
# Out:
# /var/folders/k7/ydy64qp95hd058cgvcdl7msc0000gp/T/ipykernel_33535/219559436.py:1: DtypeWarning: Columns (1,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Crime_Dataset_Coursework1.csv')

# %%
df.describe()
# Out:
#         Incident ID     CR Number        Victims       Zip Code  \
# count  3.060940e+05  3.060940e+05  306094.000000  302915.000000
# mean   2.012369e+08  1.692787e+08       1.022692   20876.535939
# std    8.626185e+04  6.210304e+07       0.192311     170.157722
# min    2.010871e+08  1.001107e+07       1.000000       6.000000
# 25%    2.011625e+08  1.705431e+08       1.000000   20853.000000
# 50%    2.012361e+08  1.900183e+08       1.000000   20878.000000
# 75%    2.013109e+08  2.000466e+08       1.000000   20904.000000
# max    2.013872e+08  2.204211e+08      22.000000   29882.000000
#
#        Address Number       Latitude      Longitude
# count    2.799850e+05  306094.000000  306094.000000
# mean     8.393001e+03      38.146328     -75.269490
# std      1.526296e+04       5.974082      11.786118
# min      1.000000e+00       0.000000     -77.516753
# 25%      1.600000e+03      39.020392     -77.197117
# 50%      8.100000e+03      39.072844     -77.099464
# ...

# %%
df.describe().transpose()
# Out:
#                    count          mean           std           min  \
# Incident ID     306094.0  2.012369e+08  8.626185e+04  2.010871e+08
# CR Number       306094.0  1.692787e+08  6.210304e+07  1.001107e+07
# Victims         306094.0  1.022692e+00  1.923108e-01  1.000000e+00
# Zip Code        302915.0  2.087654e+04  1.701577e+02  6.000000e+00
# Address Number  279985.0  8.393001e+03  1.526296e+04  1.000000e+00
# Latitude        306094.0  3.814633e+01  5.974082e+00  0.000000e+00
# Longitude       306094.0 -7.526949e+01  1.178612e+01 -7.751675e+01
#
#                          25%           50%           75%          max
# Incident ID     2.011625e+08  2.012361e+08  2.013109e+08  201387238.0
# CR Number       1.705431e+08  1.900183e+08  2.000466e+08  220421124.0
# Victims         1.000000e+00  1.000000e+00  1.000000e+00         22.0
# Zip Code        2.085300e+04  2.087800e+04  2.090400e+04      29882.0
# Address Number  1.600000e+03  8.100000e+03  1.250000e+04    2090600.0
# ...

# %%
df
# Out:
#         Incident ID Offence Code  CR Number    Dispatch Date / Time  \
# 0         201202980         3550  180042096  08/23/2018 09:52:08 PM
# 1         201181293         3522  180015424  03/30/2018 01:00:55 AM
# 2         201181293         3562  180015424  03/30/2018 01:00:55 AM
# 3         201193163         3520  180029476  06/14/2018 10:26:45 PM
# 4         201204355         2204  180043926  09/03/2018 12:06:54 PM
# ...             ...          ...        ...                     ...
# 306089    201320571         1399  210006666  02/21/2021 07:25:28 AM
# 306090    201329875         2305  210017101  05/06/2021 10:54:47 PM
# 306091    201329751         5016  210016952  05/05/2021 10:38:58 PM
# 306092    201323117         9099  210009468  03/13/2021 12:07:14 PM
# 306093    201327806         2305  210014587  04/19/2021 02:17:29 PM
#
#        NIBRS Code  Victims             Crime Name1  \
# 0             35B        1   Crime Against Society
# ...

# %%
df.dtypes
# Out:
# Incident ID                 int64
# Offence Code               object
# CR Number                   int64
# Dispatch Date / Time       object
# NIBRS Code                 object
# Victims                     int64
# Crime Name1                object
# Crime Name2                object
# Crime Name3                object
# Police District Name       object
# Block Address              object
# City                       object
# State                      object
# Zip Code                  float64
# Agency                     object
# Place                      object
# Sector                     object
# Beat                       object
# PRA                        object
# Address Number            float64
# Street Prefix              object
# Street Name                object
# Street Suffix              object
# Street Type                object
# Start_Date_Time            object
# End_Date_Time              object
# Latitude                  float64
# ...

# %%
type(df["Crime Name1"])
# Out:
# pandas.core.series.Series

# %%
df.values
# Out:
# array([[201202980, 3550, 180042096, ..., -77.265618641, '5D',
#         '(39.1777, -77.2656)'],
#        [201181293, 3522, 180015424, ..., -77.097062905, '2D',
#         '(38.9927, -77.0971)'],
#        [201181293, 3562, 180015424, ..., -77.097062905, '2D',
#         '(38.9927, -77.0971)'],
#        ...,
#        [201329751, 5016, 210016952, ..., -77.273038504, '5D',
#         '(39.1997, -77.273)'],
#        [201323117, 9099, 210009468, ..., -77.022915095, '3D',
#         '(38.9858, -77.0229)'],
#        [201327806, 2305, 210014587, ..., -77.072484929, '2D',
#         '(39.0371, -77.0725)']], dtype=object)

# %%
df.loc[0]
# Out:
# Incident ID                                      201202980
# Offence Code                                          3550
# CR Number                                        180042096
# Dispatch Date / Time                08/23/2018 09:52:08 PM
# NIBRS Code                                             35B
# Victims                                                  1
# Crime Name1                          Crime Against Society
# Crime Name2                      Drug Equipment Violations
# Crime Name3               DRUGS - NARCOTIC EQUIP - POSSESS
# Police District Name                            GERMANTOWN
# Block Address                    12800 BLK  MIDDLEBROOK RD
# City                                            GERMANTOWN
# State                                                   MD
# Zip Code                                           20874.0
# Agency                                                MCPD
# Place                                  Street - In vehicle
# ...

# %%
df.loc[2023]
# Out:
# Incident ID                                 201362064
# Offence Code                                     2611
# CR Number                                   220003727
# Dispatch Date / Time           01/28/2022 09:54:44 AM
# NIBRS Code                                        26G
# Victims                                             1
# Crime Name1                                       NaN
# Crime Name2                                       NaN
# Crime Name3                                       NaN
# Police District Name                       GERMANTOWN
# Block Address               12200 BLK  PEACH CREST DR
# City                                       GERMANTOWN
# State                                              MD
# Zip Code                                      20874.0
# Agency                                           MCPD
# Place                     Residence - Apartment/Condo
# Sector                                              N
# ...

# %%
df["Crime Name1"] = df["Crime Name1"].fillna("Other")

# %%
df
# Out:
#         Incident ID Offence Code  CR Number    Dispatch Date / Time  \
# 0         201202980         3550  180042096  08/23/2018 09:52:08 PM
# 1         201181293         3522  180015424  03/30/2018 01:00:55 AM
# 2         201181293         3562  180015424  03/30/2018 01:00:55 AM
# 3         201193163         3520  180029476  06/14/2018 10:26:45 PM
# 4         201204355         2204  180043926  09/03/2018 12:06:54 PM
# ...             ...          ...        ...                     ...
# 306089    201320571         1399  210006666  02/21/2021 07:25:28 AM
# 306090    201329875         2305  210017101  05/06/2021 10:54:47 PM
# 306091    201329751         5016  210016952  05/05/2021 10:38:58 PM
# 306092    201323117         9099  210009468  03/13/2021 12:07:14 PM
# 306093    201327806         2305  210014587  04/19/2021 02:17:29 PM
#
#        NIBRS Code  Victims             Crime Name1  \
# 0             35B        1   Crime Against Society
# ...

# %%
df.loc[2023]
# Out:
# Incident ID                                 201362064
# Offence Code                                     2611
# CR Number                                   220003727
# Dispatch Date / Time           01/28/2022 09:54:44 AM
# NIBRS Code                                        26G
# Victims                                             1
# Crime Name1                                     Other
# Crime Name2                                       NaN
# Crime Name3                                       NaN
# Police District Name                       GERMANTOWN
# Block Address               12200 BLK  PEACH CREST DR
# City                                       GERMANTOWN
# State                                              MD
# Zip Code                                      20874.0
# Agency                                           MCPD
# Place                     Residence - Apartment/Condo
# Sector                                              N
# ...

# %%
df["Crime Name2"] = df["Crime Name2"].fillna("Other")

# %%
df.loc[2023]
# Out:
# Incident ID                                 201362064
# Offence Code                                     2611
# CR Number                                   220003727
# Dispatch Date / Time           01/28/2022 09:54:44 AM
# NIBRS Code                                        26G
# Victims                                             1
# Crime Name1                                     Other
# Crime Name2                                     Other
# Crime Name3                                       NaN
# Police District Name                       GERMANTOWN
# Block Address               12200 BLK  PEACH CREST DR
# City                                       GERMANTOWN
# State                                              MD
# Zip Code                                      20874.0
# Agency                                           MCPD
# Place                     Residence - Apartment/Condo
# Sector                                              N
# ...

# %%
df["Crime Name3"] = df["Crime Name3"].fillna("Other")

# %%
df.loc[2023]
# Out:
# Incident ID                                 201362064
# Offence Code                                     2611
# CR Number                                   220003727
# Dispatch Date / Time           01/28/2022 09:54:44 AM
# NIBRS Code                                        26G
# Victims                                             1
# Crime Name1                                     Other
# Crime Name2                                     Other
# Crime Name3                                     Other
# Police District Name                       GERMANTOWN
# Block Address               12200 BLK  PEACH CREST DR
# City                                       GERMANTOWN
# State                                              MD
# Zip Code                                      20874.0
# Agency                                           MCPD
# Place                     Residence - Apartment/Condo
# Sector                                              N
# ...

# %%
df
# Out:
#         Incident ID Offence Code  CR Number    Dispatch Date / Time  \
# 0         201202980         3550  180042096  08/23/2018 09:52:08 PM
# 1         201181293         3522  180015424  03/30/2018 01:00:55 AM
# 2         201181293         3562  180015424  03/30/2018 01:00:55 AM
# 3         201193163         3520  180029476  06/14/2018 10:26:45 PM
# 4         201204355         2204  180043926  09/03/2018 12:06:54 PM
# ...             ...          ...        ...                     ...
# 306089    201320571         1399  210006666  02/21/2021 07:25:28 AM
# 306090    201329875         2305  210017101  05/06/2021 10:54:47 PM
# 306091    201329751         5016  210016952  05/05/2021 10:38:58 PM
# 306092    201323117         9099  210009468  03/13/2021 12:07:14 PM
# 306093    201327806         2305  210014587  04/19/2021 02:17:29 PM
#
#        NIBRS Code  Victims             Crime Name1  \
# 0             35B        1   Crime Against Society
# ...

# %%
df.to_csv("Crime_Dataset_Other.csv", index=False)
