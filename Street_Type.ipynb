# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv('Crime_Dataset_Cleaned.csv', low_memory=False)

# %%
df
# Out:
#         Incident ID Offence Code  CR Number Dispatch Date / Time NIBRS Code  \
# 0         201202980         3550  180042096  2018-08-23 21:52:08        35B
# 1         201181293         3522  180015424  2018-03-30 01:00:55        35A
# 2         201181293         3562  180015424  2018-03-30 01:00:55        35A
# 3         201193163         3520  180029476  2018-06-14 22:26:45        35A
# 4         201204355         2204  180043926  2018-09-03 12:06:54        220
# ...             ...          ...        ...                  ...        ...
# 306089    201320571         1399  210006666  2021-02-21 07:25:28        13B
# 306090    201329875         2305  210017101  2021-05-06 22:54:47        23F
# 306091    201329751         5016  210016952  2021-05-05 22:38:58        90Z
# 306092    201323117         9099  210009468  2021-03-13 12:07:14        90Z
# 306093    201327806         2305  210014587  2021-04-19 14:17:29        23F
#
# ...

# %% [markdown]
# # Check if there are no street types

# %%
street_type_na = df[df["Street Type"].isna()]

# %%
street_type_na
# Out:
#         Incident ID Offence Code  CR Number Dispatch Date / Time NIBRS Code  \
# 7016      201340591         9113  210030333  2021-08-04 20:35:12        90Z
# 10641     201368311         2610  220011110  2022-03-15 11:10:19        26F
# 15045     201333984         2902  210022028  2021-06-09 20:01:29        290
# 18119     201131807         9199  170504660  2017-04-28 07:37:58        90Z
# 23028     201345471         2610  210036412  2021-09-15 17:31:41        26F
# ...             ...          ...        ...                  ...        ...
# 301685    201327378         2601  210014084  2021-04-15 13:05:56        26A
# 301832    201320286         2610  210006348  2021-02-18 11:55:49        26F
# 304143    201327827         2610  210014613  2021-04-19 16:52:00        26F
# 304740    201320282         2304  210006344  2021-02-18 11:48:47        23G
# 306035    201326735         2699  210013274  2021-04-09 15:34:55        26A
#
#         Victims             Crime Name1  \
# ...

# %%
df["Crime Name1"].value_counts()
# Out:
# Crime Name1
# Crime Against Property    139882
# Crime Against Society      68917
# Other                      63450
# Crime Against Person       30270
# Not a Crime                 3575
# Name: count, dtype: int64

# %%
df["Crime Name2"].value_counts()
# Out:
# Crime Name2
# All Other Offenses                             72402
# Theft From Motor Vehicle                       26275
# Drug/Narcotic Violations                       23240
# Simple Assault                                 21063
# Destruction/Damage/Vandalism of Property       18988
# Shoplifting                                    16076
# Driving Under the Influence                    14925
# All other Larceny                              13951
# Theft from Building                            11257
# Burglary/Breaking and Entering                  8767
# Identity Theft                                  8673
# Theft of Motor Vehicle Parts or Accessories     6689
# Liquor Law Violations                           6605
# Motor Vehicle Theft                             6523
# False Pretenses/Swindle/Confidence Game         6429
# Disorderly Conduct                              4997
# Credit Card/Automatic Teller Machine Fraud      4640
# ...

# %% [markdown]
# # Create a dataset with "Crime Name2" containing "Vehicle" without empty values and missing Street Type

# %%
df = df[df["Crime Name2"].str.contains("Vehicle", na=False) & df["Street Type"].notna()]

# %%
df
# Out:
#         Incident ID Offence Code  CR Number Dispatch Date / Time NIBRS Code  \
# 5         201204355         2404  180043926  2018-09-03 12:06:54        240
# 12        201234630         2404  190016809  2019-04-11 04:44:42        240
# 53        201346532         2305  210037745  2021-09-24 05:25:58        23F
# 93        201263458         2404  190052797  2019-11-02 14:09:24        240
# 103       201276543         2305  200005949  2020-02-05 11:46:40        23F
# ...             ...          ...        ...                  ...        ...
# 306045    201319987         2305  210005946  2021-02-15 14:55:56        23F
# 306056    201328730         2401  210015216  2021-04-23 20:43:00        240
# 306078    201325385         2305  210011712  2021-03-29 12:25:35        23F
# 306090    201329875         2305  210017101  2021-05-06 22:54:47        23F
# 306093    201327806         2305  210014587  2021-04-19 14:17:29        23F
#
# ...

# %%
df.to_csv("Crime_Dataset_Street_Type.csv", index=False)

# %%
df
# Out:
#         Incident ID Offence Code  CR Number Dispatch Date / Time NIBRS Code  \
# 5         201204355         2404  180043926  2018-09-03 12:06:54        240
# 12        201234630         2404  190016809  2019-04-11 04:44:42        240
# 53        201346532         2305  210037745  2021-09-24 05:25:58        23F
# 93        201263458         2404  190052797  2019-11-02 14:09:24        240
# 103       201276543         2305  200005949  2020-02-05 11:46:40        23F
# ...             ...          ...        ...                  ...        ...
# 306045    201319987         2305  210005946  2021-02-15 14:55:56        23F
# 306056    201328730         2401  210015216  2021-04-23 20:43:00        240
# 306078    201325385         2305  210011712  2021-03-29 12:25:35        23F
# 306090    201329875         2305  210017101  2021-05-06 22:54:47        23F
# 306093    201327806         2305  210014587  2021-04-19 14:17:29        23F
#
# ...

# %%
df[df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Incident ID, Offence Code, CR Number, Dispatch Date / Time, NIBRS Code, Victims, Crime Name1, Crime Name2, Crime Name3, Police District Name, Block Address, City, State, Zip Code, Agency, Place, Sector, Beat, PRA, Address Number, Street Prefix, Street Name, Street Suffix, Street Type, Start_Date_Time, End_Date_Time, Latitude, Longitude, Police District Number, Location]
# Index: []
#
# [0 rows x 30 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df = pd.read_csv("Crime_Dataset_Street_Type.csv", low_memory=False)
df
# Out:
#        Incident ID  Offence Code  CR Number Dispatch Date / Time NIBRS Code  \
# 0        201204355          2404  180043926  2018-09-03 12:06:54        240
# 1        201234630          2404  190016809  2019-04-11 04:44:42        240
# 2        201346532          2305  210037745  2021-09-24 05:25:58        23F
# 3        201263458          2404  190052797  2019-11-02 14:09:24        240
# 4        201276543          2305  200005949  2020-02-05 11:46:40        23F
# ...            ...           ...        ...                  ...        ...
# 39448    201319987          2305  210005946  2021-02-15 14:55:56        23F
# 39449    201328730          2401  210015216  2021-04-23 20:43:00        240
# 39450    201325385          2305  210011712  2021-03-29 12:25:35        23F
# 39451    201329875          2305  210017101  2021-05-06 22:54:47        23F
# 39452    201327806          2305  210014587  2021-04-19 14:17:29        23F
#
# ...

# %%
plt.figure(figsize=(12,5), dpi=200)
sns.countplot(data=df, x="Street Type", hue="Crime Name2", palette="husl", stat="probability")
# Out:
# <Axes: xlabel='Street Type', ylabel='probability'>

# %%
df["Crime Name2"].value_counts()
# Out:
# Crime Name2
# Theft From Motor Vehicle                       26255
# Theft of Motor Vehicle Parts or Accessories     6681
# Motor Vehicle Theft                             6517
# Name: count, dtype: int64

# %%
df["Street Type"].value_counts()
# Out:
# Street Type
# DR     7731
# RD     7691
# AVE    7088
# ST     3142
# LA     2858
# CT     2545
# TER    1619
# WAY    1599
# BLV    1513
# CIR    1215
# PL     1095
# PIK     650
# HWY     340
# PKW     289
# PLZ      17
# SQ       16
# CTR      11
# RUN       8
# MEW       6
# OV        5
# CRE       4
# DRW       4
# RMP       3
# RVR       2
# ESP       1
# COV       1
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#         Incident ID  Offence Code     CR Number  Victims      Zip Code  \
# count  3.945300e+04  39453.000000  3.945300e+04  39453.0  38888.000000
# mean   2.012461e+08   2321.923098  1.723431e+08      1.0  20876.222279
# std    8.689868e+04     39.319328  6.104949e+07      0.0    180.572302
# min    2.010872e+08   2304.000000  1.004668e+07      1.0   2852.000000
# 25%    2.011679e+08   2305.000000  1.705501e+08      1.0  20853.000000
# 50%    2.012577e+08   2305.000000  1.900452e+08      1.0  20878.000000
# 75%    2.013195e+08   2305.000000  2.100053e+08      1.0  20904.000000
# max    2.013872e+08   2499.000000  2.200339e+08      1.0  29878.000000
#
#                 PRA  Address Number      Latitude     Longitude
# count  39424.000000    3.808900e+04  39453.000000  39453.000000
# mean     349.522981    7.937042e+03     38.201080    -75.384062
# std      211.034790    1.232048e+04      5.767154     11.380128
# min        0.000000    1.000000e+00      0.000000    -77.516753
# ...

# %%
plt.figure(figsize=(18,6), dpi=200)
sns.boxplot(data=df, y="Street Type", x="Crime Name2", hue="Police District Name")
# plt.xticks(rotation =90)
# Out:
# <Axes: xlabel='Crime Name2', ylabel='Street Type'>

# %%
plt.figure(figsize=(6,4), dpi=200)
sns.violinplot(data=df, y="Street Type", hue="Crime Name2", palette = "husl")
# Out:
# <Axes: ylabel='Street Type'>

# %%
df["Victims"].value_counts()
# Out:
# Victims
# 1    39453
# Name: count, dtype: int64
