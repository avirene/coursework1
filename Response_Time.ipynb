# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv('Crime_Dataset_Cleaned.csv')
# Out:
# /var/folders/k7/ydy64qp95hd058cgvcdl7msc0000gp/T/ipykernel_1536/159160125.py:1: DtypeWarning: Columns (1,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Crime_Dataset_Cleaned.csv')

# %%
df
# Out:
#         Incident ID Offence Code  CR Number Dispatch Date / Time NIBRS Code  \
# 0         201202980         3550  180042096  2018-08-23 21:52:08        35B
# 1         201181293         3522  180015424  2018-03-30 01:00:55        35A
# 2         201181293         3562  180015424  2018-03-30 01:00:55        35A
# 3         201193163         3520  180029476  2018-06-14 22:26:45        35A
# 4         201204355         2204  180043926  2018-09-03 12:06:54        220
# ...             ...          ...        ...                  ...        ...
# 306089    201320571         1399  210006666  2021-02-21 07:25:28        13B
# 306090    201329875         2305  210017101  2021-05-06 22:54:47        23F
# 306091    201329751         5016  210016952  2021-05-05 22:38:58        90Z
# 306092    201323117         9099  210009468  2021-03-13 12:07:14        90Z
# 306093    201327806         2305  210014587  2021-04-19 14:17:29        23F
#
# ...

# %%
df.describe()
# Out:
#         Incident ID     CR Number        Victims       Zip Code  \
# count  3.060940e+05  3.060940e+05  306094.000000  302915.000000
# mean   2.012369e+08  1.692787e+08       1.022692   20876.535939
# std    8.626185e+04  6.210304e+07       0.192311     170.157722
# min    2.010871e+08  1.001107e+07       1.000000       6.000000
# 25%    2.011625e+08  1.705431e+08       1.000000   20853.000000
# 50%    2.012361e+08  1.900183e+08       1.000000   20878.000000
# 75%    2.013109e+08  2.000466e+08       1.000000   20904.000000
# max    2.013872e+08  2.204211e+08      22.000000   29882.000000
#
#        Address Number       Latitude      Longitude
# count    2.799850e+05  306094.000000  306094.000000
# mean     8.393001e+03      38.146328     -75.269490
# std      1.526296e+04       5.974082      11.786118
# min      1.000000e+00       0.000000     -77.516753
# 25%      1.600000e+03      39.020392     -77.197117
# 50%      8.100000e+03      39.072844     -77.099464
# ...

# %%
df = pd.read_csv('Crime_Dataset_Cleaned.csv')
# Out:
# /var/folders/k7/ydy64qp95hd058cgvcdl7msc0000gp/T/ipykernel_1536/159160125.py:1: DtypeWarning: Columns (1,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Crime_Dataset_Cleaned.csv')

# %%
df
# Out:
#         Incident ID Offence Code  CR Number Dispatch Date / Time NIBRS Code  \
# 0         201202980         3550  180042096  2018-08-23 21:52:08        35B
# 1         201181293         3522  180015424  2018-03-30 01:00:55        35A
# 2         201181293         3562  180015424  2018-03-30 01:00:55        35A
# 3         201193163         3520  180029476  2018-06-14 22:26:45        35A
# 4         201204355         2204  180043926  2018-09-03 12:06:54        220
# ...             ...          ...        ...                  ...        ...
# 306089    201320571         1399  210006666  2021-02-21 07:25:28        13B
# 306090    201329875         2305  210017101  2021-05-06 22:54:47        23F
# 306091    201329751         5016  210016952  2021-05-05 22:38:58        90Z
# 306092    201323117         9099  210009468  2021-03-13 12:07:14        90Z
# 306093    201327806         2305  210014587  2021-04-19 14:17:29        23F
#
# ...

# %%
# check if there are no dispatch times

dispatch_na = df[df["Dispatch Date / Time"].isna()]

# %%
dispatch_na
# Out:
#         Incident ID Offence Code  CR Number Dispatch Date / Time NIBRS Code  \
# 6         201121509         5213   17008780                  NaN        520
# 7         201091648         1103   16038843                  NaN        11A
# 8         201108886         1399   16060247                  NaN        13B
# 9         201124327         9199   17012248                  NaN        90Z
# 10        201096093         2399   16044222                  NaN        23H
# ...             ...          ...        ...                  ...        ...
# 305089    201326516         2699  210013026                  NaN        26A
# 305097    201322579         1103  210008857                  NaN        11A
# 305538    201331625         1114  200050698                  NaN        11B
# 305608    201323218         2399  210009607                  NaN        23H
# 305624    201326306         2305  210012653                  NaN        23F
#
#         Victims             Crime Name1  \
# ...

# %%
# check if there are no start times

start_na = df[df["Start_Date_Time"].isna()]

# %%
start_na
# Out:
# Empty DataFrame
# Columns: [Incident ID, Offence Code, CR Number, Dispatch Date / Time, NIBRS Code, Victims, Crime Name1, Crime Name2, Crime Name3, Police District Name, Block Address, City, State, Zip Code, Agency, Place, Sector, Beat, PRA, Address Number, Street Prefix, Street Name, Street Suffix, Street Type, Start_Date_Time, End_Date_Time, Latitude, Longitude, Police District Number, Location]
# Index: []
#
# [0 rows x 30 columns]

# %%
# check if there are no district names

district_na = df[df["Police District Name"].isna()]

# %%
district_na
# Out:
#         Incident ID Offence Code  CR Number Dispatch Date / Time NIBRS Code  \
# 230       201341402         1399  210031282  2021-08-12 03:10:15        13B
# 1687      201341060         9107  210029899  2021-08-02 06:12:17        90Z
# 2178      201339152         9199  210028521  2021-07-23 10:44:41        90Z
# 2452      201338635         2799  210027897  2021-07-19 14:52:34        270
# 2855      201339765         2303  210029312  2021-07-28 19:05:00        23C
# ...             ...          ...        ...                  ...        ...
# 23107     201338552         2304  210027780  2021-07-18 18:44:11        23G
# 25184     201338793         2308  210028078  2021-07-20 18:43:46        23D
# 25399     201340496         2304  210030210  2021-08-04 09:10:17        23G
# 28045     201339480         9199  210028941  2021-07-26 14:16:27        90Z
# 301305    201331004         2399  210018487  2021-05-16 21:57:20        23H
#
#         Victims             Crime Name1  \
# ...

# %%
dispatch_district_notna = df[df["Dispatch Date / Time"].notna()]

# %%
dispatch_district_notna
# Out:
#         Incident ID Offence Code  CR Number Dispatch Date / Time NIBRS Code  \
# 0         201202980         3550  180042096  2018-08-23 21:52:08        35B
# 1         201181293         3522  180015424  2018-03-30 01:00:55        35A
# 2         201181293         3562  180015424  2018-03-30 01:00:55        35A
# 3         201193163         3520  180029476  2018-06-14 22:26:45        35A
# 4         201204355         2204  180043926  2018-09-03 12:06:54        220
# ...             ...          ...        ...                  ...        ...
# 306089    201320571         1399  210006666  2021-02-21 07:25:28        13B
# 306090    201329875         2305  210017101  2021-05-06 22:54:47        23F
# 306091    201329751         5016  210016952  2021-05-05 22:38:58        90Z
# 306092    201323117         9099  210009468  2021-03-13 12:07:14        90Z
# 306093    201327806         2305  210014587  2021-04-19 14:17:29        23F
#
# ...

# %%
dispatch_district_notna = df[df["Dispatch Date / Time"].notna() & df["Police District Name"].notna()]

# %%
dispatch_district_notna["Dispatch Date / Time"].loc[0]
# Out:
# '2018-08-23 21:52:08'

# %%
dispatch_district_notna.to_csv("Response_Times.csv", index=False)

# %%
df = pd.read_csv('Response_Times.csv')
# Out:
# /var/folders/k7/ydy64qp95hd058cgvcdl7msc0000gp/T/ipykernel_1536/1641195137.py:1: DtypeWarning: Columns (1,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Response_Times.csv')

# %%
df = pd.read_csv('Response_Times.csv', low_memory=False)

# %%
df
# Out:
#         Incident ID Offence Code  CR Number Dispatch Date / Time NIBRS Code  \
# 0         201202980         3550  180042096  2018-08-23 21:52:08        35B
# 1         201181293         3522  180015424  2018-03-30 01:00:55        35A
# 2         201181293         3562  180015424  2018-03-30 01:00:55        35A
# 3         201193163         3520  180029476  2018-06-14 22:26:45        35A
# 4         201204355         2204  180043926  2018-09-03 12:06:54        220
# ...             ...          ...        ...                  ...        ...
# 256966    201320571         1399  210006666  2021-02-21 07:25:28        13B
# 256967    201329875         2305  210017101  2021-05-06 22:54:47        23F
# 256968    201329751         5016  210016952  2021-05-05 22:38:58        90Z
# 256969    201323117         9099  210009468  2021-03-13 12:07:14        90Z
# 256970    201327806         2305  210014587  2021-04-19 14:17:29        23F
#
# ...

# %%
df.iloc[1]
# Out:
# Incident ID                                           201181293
# Offence Code                                               3522
# CR Number                                             180015424
# Dispatch Date / Time                        2018-03-30 01:00:55
# NIBRS Code                                                  35A
# Victims                                                       1
# Crime Name1                               Crime Against Society
# Crime Name2                            Drug/Narcotic Violations
# Crime Name3               DRUGS - OPIUM OR DERIVATIVE - POSSESS
# Police District Name                                   BETHESDA
# Block Address                            8300 BLK  WOODMONT AVE
# City                                                   BETHESDA
# State                                                        MD
# Zip Code                                                20814.0
# Agency                                                     MCPD
# ...

# %%
df["Dispatch Date / Time"].dtypes
# Out:
# dtype('O')

# %%
df["Dispatch Date / Time"].loc[0]
# Out:
# '2018-08-23 21:52:08'

# %%
df["Start_Date_Time"].loc[0]
# Out:
# '2018-08-23 21:52:00'

# %%
df['Dispatch Date / Time'] = pd.to_datetime(df['Dispatch Date / Time'])
df['Start_Date_Time'] = pd.to_datetime(df['Start_Date_Time'])

# %%
df["Response_Time"] = (df["Dispatch Date / Time"] - df["Start_Date_Time"]).dt.total_seconds()

# %%
df
# Out:
#         Incident ID Offence Code  CR Number Dispatch Date / Time NIBRS Code  \
# 0         201202980         3550  180042096  2018-08-23 21:52:08        35B
# 1         201181293         3522  180015424  2018-03-30 01:00:55        35A
# 2         201181293         3562  180015424  2018-03-30 01:00:55        35A
# 3         201193163         3520  180029476  2018-06-14 22:26:45        35A
# 4         201204355         2204  180043926  2018-09-03 12:06:54        220
# ...             ...          ...        ...                  ...        ...
# 256966    201320571         1399  210006666  2021-02-21 07:25:28        13B
# 256967    201329875         2305  210017101  2021-05-06 22:54:47        23F
# 256968    201329751         5016  210016952  2021-05-05 22:38:58        90Z
# 256969    201323117         9099  210009468  2021-03-13 12:07:14        90Z
# 256970    201327806         2305  210014587  2021-04-19 14:17:29        23F
#
# ...

# %%
df.iloc[1]
# Out:
# Incident ID                                           201181293
# Offence Code                                               3522
# CR Number                                             180015424
# Dispatch Date / Time                        2018-03-30 01:00:55
# NIBRS Code                                                  35A
# Victims                                                       1
# Crime Name1                               Crime Against Society
# Crime Name2                            Drug/Narcotic Violations
# Crime Name3               DRUGS - OPIUM OR DERIVATIVE - POSSESS
# Police District Name                                   BETHESDA
# Block Address                            8300 BLK  WOODMONT AVE
# City                                                   BETHESDA
# State                                                        MD
# Zip Code                                                20814.0
# Agency                                                     MCPD
# ...

# %%
df["Response_Time"].min()
# Out:
# -118261721.0

# %%
df_positive_response = df["Response_Time"] > 0

# %%
df
# Out:
#         Incident ID Offence Code  CR Number Dispatch Date / Time NIBRS Code  \
# 0         201202980         3550  180042096  2018-08-23 21:52:08        35B
# 1         201181293         3522  180015424  2018-03-30 01:00:55        35A
# 2         201181293         3562  180015424  2018-03-30 01:00:55        35A
# 3         201193163         3520  180029476  2018-06-14 22:26:45        35A
# 4         201204355         2204  180043926  2018-09-03 12:06:54        220
# ...             ...          ...        ...                  ...        ...
# 256966    201320571         1399  210006666  2021-02-21 07:25:28        13B
# 256967    201329875         2305  210017101  2021-05-06 22:54:47        23F
# 256968    201329751         5016  210016952  2021-05-05 22:38:58        90Z
# 256969    201323117         9099  210009468  2021-03-13 12:07:14        90Z
# 256970    201327806         2305  210014587  2021-04-19 14:17:29        23F
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# 1. Calculate the average response time for each police district
avg_response_time = df.groupby('Police District Name')['Response_Time'].mean().reset_index()

# 2. Sort by the response time in ascending order
avg_response_time = avg_response_time.sort_values(by='Response_Time')

# 3. Select the top N police departments with the shortest response times (for example, top 10)
top_districts = avg_response_time.head(10)

# 4. Plotting the data using seaborn
plt.figure(figsize=(10, 6))
sns.barplot(data=top_districts, x='Police District Name', y='Response_Time', palette='viridis')
plt.title('Police Departments with Shortest Average Response Times')
plt.xlabel('Police District Name')
plt.ylabel('Average Response Time (seconds)')
plt.xticks(rotation=45)
plt.show()
# Out:
# /var/folders/k7/ydy64qp95hd058cgvcdl7msc0000gp/T/ipykernel_1536/4033154242.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_districts, x='Police District Name', y='Response_Time', palette='viridis')

# %%
# 1. Calculate the average response time for each police district
avg_response_time = df.groupby('Crime Name1')['Response_Time'].mean().reset_index()

# 2. Sort by the response time in ascending order
avg_response_time = avg_response_time.sort_values(by='Response_Time')

# 3. Select the top N police departments with the shortest response times (for example, top 10)
top_districts = avg_response_time.head(10)

# 4. Plotting the data using seaborn
plt.figure(figsize=(10, 6))
sns.barplot(data=top_districts, x='Crime Name1', y='Response_Time', palette='pastel')
plt.title('Crimes with Shortest Average Response Times')
plt.xlabel('Crime Name')
plt.ylabel('Average Response Time (seconds)')
plt.xticks(rotation=45)
plt.show()
# Out:
# /var/folders/k7/ydy64qp95hd058cgvcdl7msc0000gp/T/ipykernel_1536/3025993998.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_districts, x='Crime Name1', y='Response_Time', palette='pastel')
